# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Opening a CSV file from a dircetory
#Analysis of initial dataframe
filename=pd.read_csv(
    'C:/Users/shaha/Desktop/Springboard/DataScience_Capstone2/Dataset_II/Data cleaning/File- Uncleaned_DS_jobs.csv')
df_initial=pd.DataFrame(filename)
#print(df_initial.head())
df1=df_initial.drop(columns=['index'])
print(df1.shape)
print(df1.columns)
df1
# Out:
# (672, 14)
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors'],
#       dtype='object')
#              Job Title               Salary Estimate  \
# 0    Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1       Data Scientist  $137K-$171K (Glassdoor est.)
# 2       Data Scientist  $137K-$171K (Glassdoor est.)
# 3       Data Scientist  $137K-$171K (Glassdoor est.)
# 4       Data Scientist  $137K-$171K (Glassdoor est.)
# ..                 ...                           ...
# 667     Data Scientist  $105K-$167K (Glassdoor est.)
# 668     Data Scientist  $105K-$167K (Glassdoor est.)
# 669     Data Scientist  $105K-$167K (Glassdoor est.)
# 670     Data Scientist  $105K-$167K (Glassdoor est.)
# 671     Data Scientist  $105K-$167K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# ...

# %%
#Checking the number of N/A in the dataframe
for j in range(14):
    k=0;
    for i in range(672):
        if df1.iloc[i,j]=='-1' or df1.iloc[i,j]==-1:
            k+=1
    print('Number of N/A in column ',j,'=',k)
# Out:
# Number of N/A in column  0 = 0
# Number of N/A in column  1 = 0
# Number of N/A in column  2 = 0
# Number of N/A in column  3 = 50
# Number of N/A in column  4 = 0
# Number of N/A in column  5 = 0
# Number of N/A in column  6 = 31
# Number of N/A in column  7 = 27
# Number of N/A in column  8 = 118
# Number of N/A in column  9 = 27
# Number of N/A in column  10 = 71
# Number of N/A in column  11 = 71
# Number of N/A in column  12 = 27
# Number of N/A in column  13 = 501

# %%
#fixing N/A values in the column of "Founded"
l=[]
for i in range(672):
    if df1.iloc[i,8]=='-1'or df1.iloc[i,8]==-1:
        l.append(i)
df1.drop(l,axis=0,inplace=True)

# %%
df1.shape
# Out:
# (554, 14)

# %%
for j in range(14):
    k=0;
    for i in range(554):
        if df1.iloc[i,j]=='-1' or df1.iloc[i,j]==-1:
            k+=1
    print('Number of N/A in column ',j,'=',k)
# Out:
# Number of N/A in column  0 = 0
# Number of N/A in column  1 = 0
# Number of N/A in column  2 = 0
# Number of N/A in column  3 = 1
# Number of N/A in column  4 = 0
# Number of N/A in column  5 = 0
# Number of N/A in column  6 = 0
# Number of N/A in column  7 = 0
# Number of N/A in column  8 = 0
# Number of N/A in column  9 = 0
# Number of N/A in column  10 = 3
# Number of N/A in column  11 = 3
# Number of N/A in column  12 = 0
# Number of N/A in column  13 = 385

# %%
#fixing N/A values in the column of "rating"
l=[]
for i in range(554):
    if df1.iloc[i,3]=='-1' or df1.iloc[i,3]==-1:
        l.append(i)
df1.drop(l,axis=0,inplace=True)

# %%
df1.shape
# Out:
# (553, 14)

# %%
#Checking the number of N/A in the dataframe
for j in range(14):
    k=0;
    for i in range(553):
        if df1.iloc[i,j]=='-1' or df1.iloc[i,j]==-1:
            k+=1
    print('Number of N/A in column ',j,'=',k)
# Out:
# Number of N/A in column  0 = 0
# Number of N/A in column  1 = 0
# Number of N/A in column  2 = 0
# Number of N/A in column  3 = 1
# Number of N/A in column  4 = 0
# Number of N/A in column  5 = 0
# Number of N/A in column  6 = 0
# Number of N/A in column  7 = 0
# Number of N/A in column  8 = 0
# Number of N/A in column  9 = 0
# Number of N/A in column  10 = 3
# Number of N/A in column  11 = 3
# Number of N/A in column  12 = 0
# Number of N/A in column  13 = 385

# %%
l=[]
for i in range(553):
    if df1.iloc[i,3]=='-1' or df1.iloc[i,3]==-1:
        l.append(i)
df1.drop(l,axis=0,inplace=True)

# %%
df1.shape
# Out:
# (552, 14)

# %%
for j in range(14):
    k=0;
    for i in range(552):
        if df1.iloc[i,j]=='-1' or df1.iloc[i,j]==-1:
            k+=1
    print('Number of N/A in column ',j,'=',k)
# Out:
# Number of N/A in column  0 = 0
# Number of N/A in column  1 = 0
# Number of N/A in column  2 = 0
# Number of N/A in column  3 = 1
# Number of N/A in column  4 = 0
# Number of N/A in column  5 = 0
# Number of N/A in column  6 = 0
# Number of N/A in column  7 = 0
# Number of N/A in column  8 = 0
# Number of N/A in column  9 = 0
# Number of N/A in column  10 = 3
# Number of N/A in column  11 = 3
# Number of N/A in column  12 = 0
# Number of N/A in column  13 = 384

# %%
df1['Rating']=df1['Rating'].replace(-1,1)

# %%
for j in range(14):
    k=0;
    for i in range(552):
        if df1.iloc[i,j]=='-1' or df1.iloc[i,j]==-1:
            k+=1
    print('Number of N/A in column ',j,'=',k)
# Out:
# Number of N/A in column  0 = 0
# Number of N/A in column  1 = 0
# Number of N/A in column  2 = 0
# Number of N/A in column  3 = 0
# Number of N/A in column  4 = 0
# Number of N/A in column  5 = 0
# Number of N/A in column  6 = 0
# Number of N/A in column  7 = 0
# Number of N/A in column  8 = 0
# Number of N/A in column  9 = 0
# Number of N/A in column  10 = 3
# Number of N/A in column  11 = 3
# Number of N/A in column  12 = 0
# Number of N/A in column  13 = 384

# %%
df1['Competitors']=df1['Competitors'].replace("-1","")

# %%
for j in range(14):
    k=0;
    for i in range(552):
        if df1.iloc[i,j]=='-1' or df1.iloc[i,j]==-1:
            k+=1
    print('Number of N/A in column ',j,'=',k)
# Out:
# Number of N/A in column  0 = 0
# Number of N/A in column  1 = 0
# Number of N/A in column  2 = 0
# Number of N/A in column  3 = 0
# Number of N/A in column  4 = 0
# Number of N/A in column  5 = 0
# Number of N/A in column  6 = 0
# Number of N/A in column  7 = 0
# Number of N/A in column  8 = 0
# Number of N/A in column  9 = 0
# Number of N/A in column  10 = 3
# Number of N/A in column  11 = 3
# Number of N/A in column  12 = 0
# Number of N/A in column  13 = 0

# %%
df1['Industry']=df1['Industry'].replace("-1","")

# %%
df1['Sector']=df1['Sector'].replace("-1","")

# %%
for j in range(14):
    k=0;
    for i in range(552):
        if df1.iloc[i,j]=='-1' or df1.iloc[i,j]==-1:
            k+=1
    print('Number of N/A in column ',j,'=',k)
# Out:
# Number of N/A in column  0 = 0
# Number of N/A in column  1 = 0
# Number of N/A in column  2 = 0
# Number of N/A in column  3 = 0
# Number of N/A in column  4 = 0
# Number of N/A in column  5 = 0
# Number of N/A in column  6 = 0
# Number of N/A in column  7 = 0
# Number of N/A in column  8 = 0
# Number of N/A in column  9 = 0
# Number of N/A in column  10 = 0
# Number of N/A in column  11 = 0
# Number of N/A in column  12 = 0
# Number of N/A in column  13 = 0

# %%
df2=df1.sort_values(by=['Rating'], ascending=True)
df2=df2.reset_index()
print(df2.shape)
df2
# Out:
# (552, 15)
#      index                                    Job Title  \
# 0      411                               Data Scientist
# 1      444                               Data Scientist
# 2       38                               Data Scientist
# 3      169                              Sr Data Analyst
# 4      147     Scientist - Biomarker and Flow Cytometry
# ..     ...                                          ...
# 547    382              Applied AI Scientist / Engineer
# 548     43                Scientist - Molecular Biology
# 549    507             Data Scientist - TS/SCI Required
# 550    511  Data Scientist(s)/Machine Learning Engineer
# 551    118                                NGS Scientist
#
#                   Salary Estimate  \
# 0    $124K-$198K (Glassdoor est.)
# 1     $79K-$133K (Glassdoor est.)
# 2     $75K-$131K (Glassdoor est.)
# 3    $101K-$165K (Glassdoor est.)
# 4     $90K-$109K (Glassdoor est.)
# ..                            ...
# ...

# %%
plt.hist(df2['Founded'], bins=15)
plt.title('Number of jobs founded each year')
plt.show()

# %%
plt.hist(df2['Rating'], bins=15)
plt.title('Rating')
plt.show()

# %%
df2['Rating'].describe()
# Out:
# count    552.000000
# mean       3.868116
# std        0.615526
# min        1.000000
# 25%        3.475000
# 50%        3.800000
# 75%        4.300000
# max        5.000000
# Name: Rating, dtype: float64
